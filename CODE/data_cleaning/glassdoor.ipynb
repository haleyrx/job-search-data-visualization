# %% [markdown]
# # Glassdoor Data Cleaning

# %%
import re
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from unidecode import unidecode
from langdetect import detect
import pycountry_convert as pc
from nltk.corpus import stopwords
import collections
# %matplotlib inline

# %% [markdown]
# ### Read in raw file

# %%
file = open('./glassdoor_data/columns.txt', "r")
columns = [line.strip() for line in file]
file.close()
print(list(columns))
# Out:
# ['gaTrackerData.category', 'gaTrackerData.empId', 'gaTrackerData.empName', 'gaTrackerData.empSize', 'gaTrackerData.industry', 'gaTrackerData.industryId', 'gaTrackerData.jobTitle', 'gaTrackerData.location', 'gaTrackerData.locationId', 'gaTrackerData.locationType', 'gaTrackerData.sector', 'gaTrackerData.sectorId', 'header.employerId', 'header.employerName', 'header.gocId', 'header.jobTitle', 'header.locId', 'header.location', 'header.locationType', 'header.posted', 'header.rating', 'job.description', 'job.jobTitleId', 'map.country', 'map.employerName', 'map.lat', 'map.lng', 'map.location', 'overview.industry', 'overview.industryId', 'overview.revenue', 'overview.sector', 'overview.sectorId', 'overview.size', 'overview.type', 'rating.starRating', 'salary.salaries']

# %%
df = pd.read_csv('./glassdoor_data/glassdoor.csv')

# %%
df.head()
# Out:
#    benefits.benefitRatingDecimal  benefits.comments  benefits.highlights  \
# 0                            0.0             2801.0               2801.0
# 1                            4.0             2802.0               2802.0
# 2                            0.0             2803.0               2803.0
# 3                            0.0             2804.0               2804.0
# 4                            0.0             2805.0               2805.0
#
#    benefits.numRatings benefits.employerSummary  breadCrumbs  \
# 0                    0                      NaN         2801
# 1                    3                      NaN         2802
# 2                    0                      NaN         2803
# 3                    0                      NaN         2804
# 4                    0                      NaN         2805
#
#    gaTrackerData.category  gaTrackerData.empId  gaTrackerData.empName  \
# 0                      -1              2183810            Modus Group
# 1                      -1                10416   Boehringer Ingelheim
# 2                      -1              1043373        Immobiliare.it
# 3                      -1              2226886                  Codup
# 4                      -1               851555  Markelytics Solutions
#
#   gaTrackerData.empSize  ...  salary.currency.displayName salary.currency.id  \
# 0              501-1000  ...                          NaN                NaN
# 1              10000--1  ...   United Kingdom Pound (GBP)                2.0
# 2               201-500  ...                          NaN                NaN
# 3                  1-50  ...                          NaN                NaN
# 4               201-500  ...                          NaN                NaN
#
#    salary.currency.name  salary.currency.negativeTemplate  \
# 0                   NaN                               NaN
# 1  United Kingdom Pound                              $(#)
# 2                   NaN                               NaN
# 3                   NaN                               NaN
# 4                   NaN                               NaN
#
#    salary.currency.new salary.currency.positiveTemplate  \
# 0                  NaN                              NaN
# 1                False                               $#
# 2                  NaN                              NaN
# 3                  NaN                              NaN
# 4                  NaN                              NaN
#
#   salary.currency.symbol  salary.lastSalaryDate salary.salaries wwfu
# 0                    NaN                    NaN          2483.0  NaN
# 1                &pound;    2019-10-14T06:05:58          2484.0  NaN
# 2                    NaN                    NaN          2485.0  NaN
# 3                    NaN                    NaN          2486.0  NaN
# 4                    NaN                    NaN          2487.0  NaN
#
# [5 rows x 163 columns]

# %%
df_g = df[columns]

# %%
df_g.head()
# Out:
#    gaTrackerData.category  gaTrackerData.empId  gaTrackerData.empName  \
# 0                      -1              2183810            Modus Group
# 1                      -1                10416   Boehringer Ingelheim
# 2                      -1              1043373        Immobiliare.it
# 3                      -1              2226886                  Codup
# 4                      -1               851555  Markelytics Solutions
#
#   gaTrackerData.empSize                 gaTrackerData.industry  \
# 0              501-1000  Investment Banking & Asset Management
# 1              10000--1              Biotech & Pharmaceuticals
# 2               201-500                                    NaN
# 3                  1-50                                    NaN
# 4               201-500                             Consulting
#
#    gaTrackerData.industryId  \
# 0                    200053
# 1                    200021
# 2                         0
# 3                         0
# 4                    200028
#
#                               gaTrackerData.jobTitle gaTrackerData.location  \
# 0                 Biogas Project Development Manager                 Warsaw
# 1  Quality Manager - Boehringer Ingelheim Healthc...                    NaN
# 2     Senior Software Engineer (PHP, Elixir, Python)                 Milano
# 3                                Senior SQA Engineer                Karachi
# 4                                   Research Manager              Bengaluru
#
#    gaTrackerData.locationId gaTrackerData.locationType  ... map.location  \
# 0                   3094484                       CITY  ...       Warsaw
# 1                   3183562                       CITY  ...        Porto
# 2                   2802090                       CITY  ...        Milan
# 3                   3212296                       CITY  ...      Karāchi
# 4                   2940587                       CITY  ...    Bengaluru
#
#                        overview.industry  overview.industryId  \
# 0  Investment Banking & Asset Management               200053
# 1              Biotech & Pharmaceuticals               200021
# 2                                    NaN                    0
# 3                                    NaN                    0
# 4                             Consulting               200028
#
#            overview.revenue            overview.sector overview.sectorId  \
# 0  Unknown / Non-Applicable                    Finance             10010
# 1   £5 to £10 billion (GBP)  Biotech & Pharmaceuticals             10005
# 2  £25 to £50 million (GBP)                        NaN                 0
# 3  Unknown / Non-Applicable                        NaN                 0
# 4  Unknown / Non-Applicable          Business Services             10006
#
#            overview.size      overview.type rating.starRating salary.salaries
# 0  501 to 1000 employees  Company - Private              -0.1          2483.0
# 1       10000+ employees  Company - Private               3.8          2484.0
# 2   201 to 500 employees  Company - Private               2.4          2485.0
# 3      1 to 50 employees  Company - Private               1.5          2486.0
# 4   201 to 500 employees  Company - Private               3.5          2487.0
#
# [5 rows x 37 columns]

# %%
df_g.isnull().sum().sort_values(ascending = False)
# Out:
# gaTrackerData.location        70283
# map.country                   50028
# gaTrackerData.industry        47405
# overview.industry             47405
# overview.sector               47373
# gaTrackerData.sector          47373
# rating.starRating             18391
# gaTrackerData.empName         18209
# gaTrackerData.empSize         18209
# overview.type                 18209
# overview.size                 18209
# overview.revenue              18209
# salary.salaries               18141
# map.employerName              18141
# header.employerName            3245
# header.locationType              23
# header.location                   5
# map.location                      5
# job.description                   4
# header.locId                      0
# header.employerId                 0
# gaTrackerData.industryId          0
# gaTrackerData.jobTitle            0
# gaTrackerData.locationId          0
# overview.sectorId                 0
# gaTrackerData.locationType        0
# gaTrackerData.sectorId            0
# overview.industryId               0
# map.lng                           0
# map.lat                           0
# header.gocId                      0
# header.jobTitle                   0
# job.jobTitleId                    0
# header.rating                     0
# header.posted                     0
# gaTrackerData.empId               0
# gaTrackerData.category            0
# dtype: int64

# %% [markdown]
# ### Clean up country names

# %%
# get country codes
country_codes = pd.read_csv("./glassdoor_data/country_names_2_digit_codes.csv")

# %%
country_codes.head()
# Out:
#              Name Code
# 0     Afghanistan   AF
# 1  Ã…land Islands   AX
# 2         Albania   AL
# 3         Algeria   DZ
# 4  American Samoa   AS

# %%
# drop nans for country data
listings_before = df_g.shape[0]
print(f'Initial Glassdoor dataset length is {listings_before} job listings.')

df_g.dropna(subset=['map.country'], inplace=True)

listings_after = df_g.shape[0]
print(f'After removing NaN countries we were left with {listings_after} job listings.')
# Out:
# Initial Glassdoor dataset length is 165290 job listings.
# After removing NaN countries we were left with 115262 job listings.
# <ipython-input-15-5c9a97b82ee8>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_g.dropna(subset=['map.country'], inplace=True)

# %%
df_g = pd.merge(df_g, country_codes, left_on='map.country', right_on='Code', how='left')
df_g.head()
# Out:
#    gaTrackerData.category  gaTrackerData.empId  gaTrackerData.empName  \
# 0                      -1              2183810            Modus Group
# 1                      -1              1043373        Immobiliare.it
# 2                      -1              2226886                  Codup
# 3                      -1               851555  Markelytics Solutions
# 4                      -1               556626            Nisha Group
#
#   gaTrackerData.empSize                 gaTrackerData.industry  \
# 0              501-1000  Investment Banking & Asset Management
# 1               201-500                                    NaN
# 2                  1-50                                    NaN
# 3               201-500                             Consulting
# 4                51-200                 Staffing & Outsourcing
#
#    gaTrackerData.industryId                          gaTrackerData.jobTitle  \
# 0                    200053              Biogas Project Development Manager
# 1                         0  Senior Software Engineer (PHP, Elixir, Python)
# 2                         0                             Senior SQA Engineer
# 3                    200028                                Research Manager
# 4                    200032                             B2B Product Manager
#
#   gaTrackerData.location  gaTrackerData.locationId gaTrackerData.locationType  \
# 0                 Warsaw                   3094484                       CITY
# 1                 Milano                   2802090                       CITY
# 2                Karachi                   3212296                       CITY
# 3              Bengaluru                   2940587                       CITY
# 4                    NaN                        -1                       CITY
#
#    ... overview.industryId          overview.revenue    overview.sector  \
# 0  ...              200053  Unknown / Non-Applicable            Finance
# 1  ...                   0  £25 to £50 million (GBP)                NaN
# 2  ...                   0  Unknown / Non-Applicable                NaN
# 3  ...              200028  Unknown / Non-Applicable  Business Services
# 4  ...              200032  Unknown / Non-Applicable  Business Services
#
#   overview.sectorId          overview.size      overview.type  \
# 0             10010  501 to 1000 employees  Company - Private
# 1                 0   201 to 500 employees  Company - Private
# 2                 0      1 to 50 employees  Company - Private
# 3             10006   201 to 500 employees  Company - Private
# 4             10006    51 to 200 employees  Company - Private
#
#    rating.starRating salary.salaries      Name Code
# 0               -0.1          2483.0       NaN  NaN
# 1                2.4          2485.0       NaN  NaN
# 2                1.5          2486.0  Pakistan   PK
# 3                3.5          2487.0     India   IN
# 4                3.5          2489.0    Israel   IL
#
# [5 rows x 39 columns]

# %%
df_g['map.country'] = df_g.Name.fillna(df_g['map.country'] )
df_g[['gaTrackerData.location', 'map.country', 'Name', 'Code']].head()
df_g.head()
# Out:
#    gaTrackerData.category  gaTrackerData.empId  gaTrackerData.empName  \
# 0                      -1              2183810            Modus Group
# 1                      -1              1043373        Immobiliare.it
# 2                      -1              2226886                  Codup
# 3                      -1               851555  Markelytics Solutions
# 4                      -1               556626            Nisha Group
#
#   gaTrackerData.empSize                 gaTrackerData.industry  \
# 0              501-1000  Investment Banking & Asset Management
# 1               201-500                                    NaN
# 2                  1-50                                    NaN
# 3               201-500                             Consulting
# 4                51-200                 Staffing & Outsourcing
#
#    gaTrackerData.industryId                          gaTrackerData.jobTitle  \
# 0                    200053              Biogas Project Development Manager
# 1                         0  Senior Software Engineer (PHP, Elixir, Python)
# 2                         0                             Senior SQA Engineer
# 3                    200028                                Research Manager
# 4                    200032                             B2B Product Manager
#
#   gaTrackerData.location  gaTrackerData.locationId gaTrackerData.locationType  \
# 0                 Warsaw                   3094484                       CITY
# 1                 Milano                   2802090                       CITY
# 2                Karachi                   3212296                       CITY
# 3              Bengaluru                   2940587                       CITY
# 4                    NaN                        -1                       CITY
#
#    ... overview.industryId          overview.revenue    overview.sector  \
# 0  ...              200053  Unknown / Non-Applicable            Finance
# 1  ...                   0  £25 to £50 million (GBP)                NaN
# 2  ...                   0  Unknown / Non-Applicable                NaN
# 3  ...              200028  Unknown / Non-Applicable  Business Services
# 4  ...              200032  Unknown / Non-Applicable  Business Services
#
#   overview.sectorId          overview.size      overview.type  \
# 0             10010  501 to 1000 employees  Company - Private
# 1                 0   201 to 500 employees  Company - Private
# 2                 0      1 to 50 employees  Company - Private
# 3             10006   201 to 500 employees  Company - Private
# 4             10006    51 to 200 employees  Company - Private
#
#    rating.starRating salary.salaries      Name Code
# 0               -0.1          2483.0       NaN  NaN
# 1                2.4          2485.0       NaN  NaN
# 2                1.5          2486.0  Pakistan   PK
# 3                3.5          2487.0     India   IN
# 4                3.5          2489.0    Israel   IL
#
# [5 rows x 39 columns]

# %%
df_g = df_g.drop(columns=['Name', 'Code'])
df_g[['gaTrackerData.location', 'map.country']].head()
# Out:
#   gaTrackerData.location map.country
# 0                 Warsaw      Poland
# 1                 Milano       Italy
# 2                Karachi    Pakistan
# 3              Bengaluru       India
# 4                    NaN      Israel

# %%
listings_before = df_g.shape[0]

# Now we merge two dataframes by Country and Name
df_g = pd.merge(df_g, country_codes, left_on='map.country', right_on='Name', how='left')
df_g.head()
# Out:
#    gaTrackerData.category  gaTrackerData.empId  gaTrackerData.empName  \
# 0                      -1              2183810            Modus Group
# 1                      -1              1043373        Immobiliare.it
# 2                      -1              2226886                  Codup
# 3                      -1               851555  Markelytics Solutions
# 4                      -1               556626            Nisha Group
#
#   gaTrackerData.empSize                 gaTrackerData.industry  \
# 0              501-1000  Investment Banking & Asset Management
# 1               201-500                                    NaN
# 2                  1-50                                    NaN
# 3               201-500                             Consulting
# 4                51-200                 Staffing & Outsourcing
#
#    gaTrackerData.industryId                          gaTrackerData.jobTitle  \
# 0                    200053              Biogas Project Development Manager
# 1                         0  Senior Software Engineer (PHP, Elixir, Python)
# 2                         0                             Senior SQA Engineer
# 3                    200028                                Research Manager
# 4                    200032                             B2B Product Manager
#
#   gaTrackerData.location  gaTrackerData.locationId gaTrackerData.locationType  \
# 0                 Warsaw                   3094484                       CITY
# 1                 Milano                   2802090                       CITY
# 2                Karachi                   3212296                       CITY
# 3              Bengaluru                   2940587                       CITY
# 4                    NaN                        -1                       CITY
#
#    ... overview.industryId          overview.revenue    overview.sector  \
# 0  ...              200053  Unknown / Non-Applicable            Finance
# 1  ...                   0  £25 to £50 million (GBP)                NaN
# 2  ...                   0  Unknown / Non-Applicable                NaN
# 3  ...              200028  Unknown / Non-Applicable  Business Services
# 4  ...              200032  Unknown / Non-Applicable  Business Services
#
#   overview.sectorId          overview.size      overview.type  \
# 0             10010  501 to 1000 employees  Company - Private
# 1                 0   201 to 500 employees  Company - Private
# 2                 0      1 to 50 employees  Company - Private
# 3             10006   201 to 500 employees  Company - Private
# 4             10006    51 to 200 employees  Company - Private
#
#    rating.starRating salary.salaries      Name Code
# 0               -0.1          2483.0    Poland   PL
# 1                2.4          2485.0     Italy   IT
# 2                1.5          2486.0  Pakistan   PK
# 3                3.5          2487.0     India   IN
# 4                3.5          2489.0    Israel   IL
#
# [5 rows x 39 columns]

# %%
# And remove rows were Name is NaN
df_g.dropna(subset=['Name'], inplace=True)
df_g = df_g.drop(['Name', 'Code'], axis=1)
listings_after =df_g.shape[0]
print(f'Remaining job listings: {listings_after}')
# Out:
# Remaining job listings: 109555

# %%
df_g.isnull().sum().sort_values(ascending = False)
# Out:
# gaTrackerData.industry        41410
# overview.industry             41410
# gaTrackerData.sector          41378
# overview.sector               41378
# gaTrackerData.location        21264
# rating.starRating             15327
# overview.revenue              15176
# gaTrackerData.empName         15176
# gaTrackerData.empSize         15176
# overview.type                 15176
# overview.size                 15176
# map.employerName              15111
# salary.salaries               15111
# header.employerName            1027
# overview.industryId               0
# job.jobTitleId                    0
# map.location                      0
# map.lng                           0
# map.lat                           0
# overview.sectorId                 0
# map.country                       0
# gaTrackerData.category            0
# job.description                   0
# header.rating                     0
# header.posted                     0
# gaTrackerData.empId               0
# header.location                   0
# header.locId                      0
# header.jobTitle                   0
# header.gocId                      0
# header.employerId                 0
# gaTrackerData.sectorId            0
# gaTrackerData.locationType        0
# gaTrackerData.locationId          0
# gaTrackerData.jobTitle            0
# gaTrackerData.industryId          0
# header.locationType               0
# dtype: int64

# %% [markdown]
# ### Clean up job titles

# %%
def parse_title(title):
    title_lower = title.lower()
    
    title_list = ['data scientist', 'software engineer', 'data analyst', 'research scientist', 'business analyst',
                  'data engineer', 'statistician', 'dba', 'database engineer', 'machine learning engineer', 'applied scientist',
                 'business intelligence', 'product manager', 'sales']
    
    for val in title_list:
        if val in title_lower:
            return val.title()
   
    return title_lower.title()

# %%
df_g['Job Title'] = df_g['gaTrackerData.jobTitle'].apply(parse_title)

# %%
df_g['Job Title'].value_counts()
# Out:
# Software Engineer                                                       10827
# Business Analyst                                                         6706
# Product Manager                                                          5594
# Data Scientist                                                           4625
# Data Analyst                                                             4165
#                                                                         ...
# Consultant : Business & Process Analyst, Project & Change Management        1
# Information Engineer                                                        1
# Senior Speech Recognition Scientist                                         1
# Insurance Product - It Manager                                              1
# Field Research Associate                                                    1
# Name: Job Title, Length: 29942, dtype: int64

# %% [markdown]
# ### Clean dataframe for Tableau Map

# %%
glassdoor = df_g[['Job Title', 'gaTrackerData.empName', 'gaTrackerData.empSize', 'gaTrackerData.industry', 'gaTrackerData.location', 'gaTrackerData.sector', 'header.jobTitle', 'map.country', 'overview.type', 'rating.starRating']]
glassdoor.rename(columns={'gaTrackerData.empName': 'Employer Name', 
                          'gaTrackerData.empSize': 'Employer Size',
                          'gaTrackerData.industry': 'Industry',
                          'gaTrackerData.location': 'Location',
                          'gaTrackerData.sector': 'Sector',
                          'header.jobTitle': 'Listing Job Title',
                          'map.country': 'Country',
                          'overview.type': 'Company Type',
                          'rating.starRating': 'Company Rating'
                         }, 
                            inplace=True)
glassdoor.head()
# Out:
# /Users/haleyxue/opt/anaconda3/envs/jobs_project/lib/python3.9/site-packages/pandas/core/frame.py:4441: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(
#                             Job Title          Employer Name Employer Size  \
# 0  Biogas Project Development Manager            Modus Group      501-1000
# 1                   Software Engineer        Immobiliare.it        201-500
# 2                 Senior Sqa Engineer                  Codup          1-50
# 3                    Research Manager  Markelytics Solutions       201-500
# 4                     Product Manager            Nisha Group        51-200
#
#                                 Industry   Location             Sector  \
# 0  Investment Banking & Asset Management     Warsaw            Finance
# 1                                    NaN     Milano                NaN
# 2                                    NaN    Karachi                NaN
# 3                             Consulting  Bengaluru  Business Services
# 4                 Staffing & Outsourcing        NaN  Business Services
#
#                                 Listing Job Title   Country  \
# 0              Biogas Project Development Manager    Poland
# 1  Senior Software Engineer (PHP, Elixir, Python)     Italy
# 2                             Senior SQA Engineer  Pakistan
# 3                                Research Manager     India
# 4                             B2B Product Manager    Israel
#
#         Company Type  Company Rating
# 0  Company - Private            -0.1
# 1  Company - Private             2.4
# 2  Company - Private             1.5
# 3  Company - Private             3.5
# 4  Company - Private             3.5

# %%
len(glassdoor)
# Out:
# 109555

# %%
# save dataframe 
glassdoor.to_excel('./glassdoor_map_tableau.xlsx',engine='xlsxwriter')

# %% [markdown]
# ## Clean job descriptions

# %%
descriptions = df_g[['Job Title', 'gaTrackerData.empName', 'gaTrackerData.empSize', 'gaTrackerData.industry', 
                  'gaTrackerData.location', 'gaTrackerData.sector', 'header.jobTitle', 'map.country', 
                  'overview.type', 'rating.starRating', 'job.description']]

descriptions.rename(columns={'gaTrackerData.empName': 'Employer Name', 
                          'gaTrackerData.empSize': 'Employer Size',
                          'gaTrackerData.industry': 'Industry',
                          'gaTrackerData.location': 'Location',
                          'gaTrackerData.sector': 'Sector',
                          'header.jobTitle': 'Listing Job Title',
                          'map.country': 'Country',
                          'overview.type': 'Company Type',
                          'rating.starRating': 'Company Rating',
                          'job.description': 'Job Description'}, 
                            inplace=True)

descriptions.head()
# Out:
# /Users/haleyxue/opt/anaconda3/envs/jobs_project/lib/python3.9/site-packages/pandas/core/frame.py:4441: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(
#                             Job Title          Employer Name Employer Size  \
# 0  Biogas Project Development Manager            Modus Group      501-1000
# 1                   Software Engineer        Immobiliare.it        201-500
# 2                 Senior Sqa Engineer                  Codup          1-50
# 3                    Research Manager  Markelytics Solutions       201-500
# 4                     Product Manager            Nisha Group        51-200
#
#                                 Industry   Location             Sector  \
# 0  Investment Banking & Asset Management     Warsaw            Finance
# 1                                    NaN     Milano                NaN
# 2                                    NaN    Karachi                NaN
# 3                             Consulting  Bengaluru  Business Services
# 4                 Staffing & Outsourcing        NaN  Business Services
#
#                                 Listing Job Title   Country  \
# 0              Biogas Project Development Manager    Poland
# 1  Senior Software Engineer (PHP, Elixir, Python)     Italy
# 2                             Senior SQA Engineer  Pakistan
# 3                                Research Manager     India
# 4                             B2B Product Manager    Israel
#
#         Company Type  Company Rating  \
# 0  Company - Private            -0.1
# 1  Company - Private             2.4
# 2  Company - Private             1.5
# 3  Company - Private             3.5
# 4  Company - Private             3.5
#
#                                      Job Description
# 0  We are the drivers of the future who offer a g...
# 1  Dottori.it &egrave; il motore di ricerca che t...
# 2  Codup is looking for a Senior SQA Engineer for...
# 3  <strong>Department:</strong> Research &amp; Op...
# 4  <b>&#1514;&#1497;&#1488;&#1493;&#1512; &#1492;...

# %%
# get only jobs of interest

title_list = ['data scientist', 'software engineer', 'data analyst', 'research scientist', 'business analyst',
              'data engineer', 'statistician', 'dba', 'database engineer', 'machine learning engineer', 'applied scientist',
             'business intelligence', 'product manager', 'sales']

filter_list =[]

for t in title_list:
    filter_list.append(t.title())
    
skills = descriptions[descriptions['Job Title'].isin(filter_list)]

# %%
# Filter for English descriptions
def replace_html(text):
    re_expression = '(<\w+>|</\w+>|\\n|<\w+/>|&quot;|&egrave|http\S+|[-|0-9]|\*|,|;|&)'
    clean_text = re.sub(re_expression, ' ', text)
    ready_text = unidecode(clean_text.lower())
    return ready_text

# %%
skills['Job Description'] = skills['Job Description'].map(replace_html)
skills.head(5)
# Out:
# <ipython-input-32-be71c2764000>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   skills['Job Description'] = skills['Job Description'].map(replace_html)
#             Job Title                      Employer Name Employer Size  \
# 1   Software Engineer                    Immobiliare.it        201-500
# 4     Product Manager                        Nisha Group        51-200
# 8     Product Manager  HSBC Global Technology (HSBC GLT)          -1-0
# 11       Data Analyst                             Amaris    5001-10000
# 13   Business Analyst                          Accenture      10000--1
#
#                   Industry  Location             Sector  \
# 1                      NaN    Milano                NaN
# 4   Staffing & Outsourcing       NaN  Business Services
# 8    Banks & Credit Unions       NaN            Finance
# 11              Consulting  Brussels  Business Services
# 13              Consulting     Paris  Business Services
#
#                                     Listing Job Title    Country  \
# 1      Senior Software Engineer (PHP, Elixir, Python)      Italy
# 4                                 B2B Product Manager     Israel
# 8   Digital Product Manager, Digital Customer Onbo...  Hong Kong
# 11                                   Big Data Analyst    Belgium
# 13  Business Analyst IFRS 17 Implementation Paris F/H     France
#
#          Company Type  Company Rating  \
# 1   Company - Private             2.4
# 4   Company - Private             3.5
# 8   Company - Private             3.8
# 11  Company - Private             3.0
# 13   Company - Public             3.7
#
#                                       Job Description
# 1   dottori.it    il motore di ricerca che ti aiut...
# 4     #      #      #      #      #       #      #...
# 8   some careers grow faster than others.    if yo...
# 11  amaris est une soci eacute t eacute  ind eacut...
# 13   business analyst paris f/h     contrat : cdi ...

# %%
def get_language(text):
    try:
        lang = detect(text)
    except:
        lang = 'Error'
    return lang

# %%
skills['Language'] = skills['Job Description'].apply(get_language)
skills.head()
# Out:
# <ipython-input-39-62f56bd0f750>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   skills['Language'] = skills['Job Description'].apply(get_language)
#             Job Title                      Employer Name Employer Size  \
# 1   Software Engineer                    Immobiliare.it        201-500
# 4     Product Manager                        Nisha Group        51-200
# 8     Product Manager  HSBC Global Technology (HSBC GLT)          -1-0
# 11       Data Analyst                             Amaris    5001-10000
# 13   Business Analyst                          Accenture      10000--1
#
#                   Industry  Location             Sector  \
# 1                      NaN    Milano                NaN
# 4   Staffing & Outsourcing       NaN  Business Services
# 8    Banks & Credit Unions       NaN            Finance
# 11              Consulting  Brussels  Business Services
# 13              Consulting     Paris  Business Services
#
#                                     Listing Job Title    Country  \
# 1      Senior Software Engineer (PHP, Elixir, Python)      Italy
# 4                                 B2B Product Manager     Israel
# 8   Digital Product Manager, Digital Customer Onbo...  Hong Kong
# 11                                   Big Data Analyst    Belgium
# 13  Business Analyst IFRS 17 Implementation Paris F/H     France
#
#          Company Type  Company Rating  \
# 1   Company - Private             2.4
# 4   Company - Private             3.5
# 8   Company - Private             3.8
# 11  Company - Private             3.0
# 13   Company - Public             3.7
#
#                                       Job Description Language
# 1   dottori.it    il motore di ricerca che ti aiut...       it
# 4     #      #      #      #      #       #      #...       fr
# 8   some careers grow faster than others.    if yo...       en
# 11  amaris est une soci eacute t eacute  ind eacut...       fr
# 13   business analyst paris f/h     contrat : cdi ...       fr

# %%
# save a copy 
skills.to_excel('./glassdoor_lang.xlsx',engine='xlsxwriter')

# %%
english = skills[skills['Language']=='en']
english.drop(columns=['Language'], inplace=True)
english.head()
# Out:
# /Users/haleyxue/opt/anaconda3/envs/jobs_project/lib/python3.9/site-packages/pandas/core/frame.py:4308: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
#            Job Title                      Employer Name Employer Size  \
# 8    Product Manager  HSBC Global Technology (HSBC GLT)          -1-0
# 14    Data Scientist                            Harnham        51-200
# 16             Sales                   Rentokil Initial      10000--1
# 20    Data Scientist                          Derbysoft        51-200
# 21  Business Analyst                           TrackTik        51-200
#
#                          Industry       Location                  Sector  \
# 8           Banks & Credit Unions            NaN                 Finance
# 14         Staffing & Outsourcing  Charing Cross       Business Services
# 16  Building & Personnel Services          Perai       Business Services
# 20                    IT Services      Barcelona  Information Technology
# 21   Computer Hardware & Software       Montréal  Information Technology
#
#                                     Listing Job Title         Country  \
# 8   Digital Product Manager, Digital Customer Onbo...       Hong Kong
# 14                               Data Scientist media  United Kingdom
# 16  Territory Manager (Outdoor Sales Consultant), ...        Malaysia
# 20                                     Data Scientist           Spain
# 21                                   Business Analyst          Canada
#
#          Company Type  Company Rating  \
# 8   Company - Private             3.8
# 14  Company - Private             4.1
# 16   Company - Public             4.4
# 20  Company - Private             3.8
# 21  Company - Private             4.2
#
#                                       Job Description
# 8   some careers grow faster than others.    if yo...
# 14      data scientist media      london       pou...
# 16   rentokil initial:     rentokil initial is an ...
# 20   job title:  data scientist     business unit:...
# 21   about tracktik     tracktik is a montreal bas...

# %%
# Get continent
english = pd.merge(english, country_codes, left_on='Country', right_on='Name', how='left')
english['Region'] = english['Code'] .apply(pc.country_alpha2_to_continent_code)
english.head()
# Out:
#           Job Title                      Employer Name Employer Size  \
# 0   Product Manager  HSBC Global Technology (HSBC GLT)          -1-0
# 1    Data Scientist                            Harnham        51-200
# 2             Sales                   Rentokil Initial      10000--1
# 3    Data Scientist                          Derbysoft        51-200
# 4  Business Analyst                           TrackTik        51-200
#
#                         Industry       Location                  Sector  \
# 0          Banks & Credit Unions            NaN                 Finance
# 1         Staffing & Outsourcing  Charing Cross       Business Services
# 2  Building & Personnel Services          Perai       Business Services
# 3                    IT Services      Barcelona  Information Technology
# 4   Computer Hardware & Software       Montréal  Information Technology
#
#                                    Listing Job Title         Country  \
# 0  Digital Product Manager, Digital Customer Onbo...       Hong Kong
# 1                               Data Scientist media  United Kingdom
# 2  Territory Manager (Outdoor Sales Consultant), ...        Malaysia
# 3                                     Data Scientist           Spain
# 4                                   Business Analyst          Canada
#
#         Company Type  Company Rating  \
# 0  Company - Private             3.8
# 1  Company - Private             4.1
# 2   Company - Public             4.4
# 3  Company - Private             3.8
# 4  Company - Private             4.2
#
#                                      Job Description            Name Code  \
# 0  some careers grow faster than others.    if yo...       Hong Kong   HK
# 1      data scientist media      london       pou...  United Kingdom   GB
# 2   rentokil initial:     rentokil initial is an ...        Malaysia   MY
# 3   job title:  data scientist     business unit:...           Spain   ES
# 4   about tracktik     tracktik is a montreal bas...          Canada   CA
#
#   Region
# 0     AS
# 1     EU
# 2     AS
# 3     EU
# 4     NA

# %%
english.drop(columns=['Name'], inplace=True)
english['Region'].unique()
# Out:
# array(['AS', 'EU', 'NA', 'AF', 'OC', 'SA'], dtype=object)

# %%
def get_cont_name(code): 
    cont_conv_dict = {'AF': 'Africa',
                  'NA': 'North America',
                  'OC': 'Oceania',
                  'AN': 'Antarctica',
                  'AS': 'Asia',
                  'EU': 'Europe',
                  'SA': 'South America'}
    return cont_conv_dict[code] 

english['Region'] = english['Region'].apply(get_cont_name)
english.head()
# Out:
#           Job Title                      Employer Name Employer Size  \
# 0   Product Manager  HSBC Global Technology (HSBC GLT)          -1-0
# 1    Data Scientist                            Harnham        51-200
# 2             Sales                   Rentokil Initial      10000--1
# 3    Data Scientist                          Derbysoft        51-200
# 4  Business Analyst                           TrackTik        51-200
#
#                         Industry       Location                  Sector  \
# 0          Banks & Credit Unions            NaN                 Finance
# 1         Staffing & Outsourcing  Charing Cross       Business Services
# 2  Building & Personnel Services          Perai       Business Services
# 3                    IT Services      Barcelona  Information Technology
# 4   Computer Hardware & Software       Montréal  Information Technology
#
#                                    Listing Job Title         Country  \
# 0  Digital Product Manager, Digital Customer Onbo...       Hong Kong
# 1                               Data Scientist media  United Kingdom
# 2  Territory Manager (Outdoor Sales Consultant), ...        Malaysia
# 3                                     Data Scientist           Spain
# 4                                   Business Analyst          Canada
#
#         Company Type  Company Rating  \
# 0  Company - Private             3.8
# 1  Company - Private             4.1
# 2   Company - Public             4.4
# 3  Company - Private             3.8
# 4  Company - Private             4.2
#
#                                      Job Description Code         Region
# 0  some careers grow faster than others.    if yo...   HK           Asia
# 1      data scientist media      london       pou...   GB         Europe
# 2   rentokil initial:     rentokil initial is an ...   MY           Asia
# 3   job title:  data scientist     business unit:...   ES         Europe
# 4   about tracktik     tracktik is a montreal bas...   CA  North America

# %%
stop = stopwords.words('english')
english['Cleaned Description'] = english['Job Description'].apply(lambda x: ' '.join([word for word in x.split() if word not in (stop)]))
english.head()
# Out:
#           Job Title                      Employer Name Employer Size  \
# 0   Product Manager  HSBC Global Technology (HSBC GLT)          -1-0
# 1    Data Scientist                            Harnham        51-200
# 2             Sales                   Rentokil Initial      10000--1
# 3    Data Scientist                          Derbysoft        51-200
# 4  Business Analyst                           TrackTik        51-200
#
#                         Industry       Location                  Sector  \
# 0          Banks & Credit Unions            NaN                 Finance
# 1         Staffing & Outsourcing  Charing Cross       Business Services
# 2  Building & Personnel Services          Perai       Business Services
# 3                    IT Services      Barcelona  Information Technology
# 4   Computer Hardware & Software       Montréal  Information Technology
#
#                                    Listing Job Title         Country  \
# 0  Digital Product Manager, Digital Customer Onbo...       Hong Kong
# 1                               Data Scientist media  United Kingdom
# 2  Territory Manager (Outdoor Sales Consultant), ...        Malaysia
# 3                                     Data Scientist           Spain
# 4                                   Business Analyst          Canada
#
#         Company Type  Company Rating  \
# 0  Company - Private             3.8
# 1  Company - Private             4.1
# 2   Company - Public             4.4
# 3  Company - Private             3.8
# 4  Company - Private             4.2
#
#                                      Job Description Code         Region  \
# 0  some careers grow faster than others.    if yo...   HK           Asia
# 1      data scientist media      london       pou...   GB         Europe
# 2   rentokil initial:     rentokil initial is an ...   MY           Asia
# 3   job title:  data scientist     business unit:...   ES         Europe
# 4   about tracktik     tracktik is a montreal bas...   CA  North America
#
#                                  Cleaned Description
# 0  careers grow faster others. rsquo looking care...
# 1  data scientist media london pound pound + bene...
# 2  rentokil initial: rentokil initial internation...
# 3  job title: data scientist business unit: marke...
# 4  tracktik tracktik montreal based saas scale co...

# %%
english.to_excel('./tableau_worldcloud.xlsx',engine='xlsxwriter')

# %%
# doc_frequency = Counter() # This will create a full counter of our terms. 
# [doc_frequency.update(item) for item in job_descriptions] # List comp
    
#     # Now we can just look at our final dict list inside doc_frequency
    
#     # Obtain our key terms and store them in a dict. These are the key data science skills we are looking for
    
#     prog_lang_dict = Counter({'R':doc_frequency['r'], 'Python':doc_frequency['python'],
#                     'Java':doc_frequency['java'], 'C++':doc_frequency['c++'],
#                     'Ruby':doc_frequency['ruby'],
#                     'Perl':doc_frequency['perl'], 'Matlab':doc_frequency['matlab'],
#                     'JavaScript':doc_frequency['javascript'], 'Scala': doc_frequency['scala']})
                      
#     analysis_tool_dict = Counter({'Excel':doc_frequency['excel'],  'Tableau':doc_frequency['tableau'],
#                         'D3.js':doc_frequency['d3.js'], 'SAS':doc_frequency['sas'],
#                         'SPSS':doc_frequency['spss'], 'D3':doc_frequency['d3']})  

#     hadoop_dict = Counter({'Hadoop':doc_frequency['hadoop'], 'MapReduce':doc_frequency['mapreduce'],
#                 'Spark':doc_frequency['spark'], 'Pig':doc_frequency['pig'],
#                 'Hive':doc_frequency['hive'], 'Shark':doc_frequency['shark'],
#                 'Oozie':doc_frequency['oozie'], 'ZooKeeper':doc_frequency['zookeeper'],
#                 'Flume':doc_frequency['flume'], 'Mahout':doc_frequency['mahout']})
                
#     database_dict = Counter({'SQL':doc_frequency['sql'], 'NoSQL':doc_frequency['nosql'],
#                     'HBase':doc_frequency['hbase'], 'Cassandra':doc_frequency['cassandra'],
#                     'MongoDB':doc_frequency['mongodb']})
                     
               
#     overall_total_skills = prog_lang_dict + analysis_tool_dict + hadoop_dict + database_dict # Combine our Counter objects
    
        
    
#     final_frame = pd.DataFrame(overall_total_skills.items(), columns = ['Term', 'NumPostings']) # Convert these terms to a 
#                                                                                                 # dataframe 
    
#     # Change the values to reflect a percentage of the postings 
    
#     final_frame.NumPostings = (final_frame.NumPostings)*100/len(job_descriptions) # Gives percentage of job postings 
#                                                                                     #  having that term 
    
#     # Sort the data for plotting purposes
    
#     final_frame.sort(columns = 'NumPostings', ascending = False, inplace = True)
# Out:
#    gaTrackerData.category  gaTrackerData.empId  gaTrackerData.empName  \
# 0                      -1              2183810            Modus Group
# 1                      -1              1043373        Immobiliare.it
# 2                      -1              2226886                  Codup
# 3                      -1               851555  Markelytics Solutions
# 4                      -1               556626            Nisha Group
#
#   gaTrackerData.empSize                 gaTrackerData.industry  \
# 0              501-1000  Investment Banking & Asset Management
# 1               201-500                                    NaN
# 2                  1-50                                    NaN
# 3               201-500                             Consulting
# 4                51-200                 Staffing & Outsourcing
#
#    gaTrackerData.industryId                          gaTrackerData.jobTitle  \
# 0                    200053              Biogas Project Development Manager
# 1                         0  Senior Software Engineer (PHP, Elixir, Python)
# 2                         0                             Senior SQA Engineer
# 3                    200028                                Research Manager
# 4                    200032                             B2B Product Manager
#
#   gaTrackerData.location  gaTrackerData.locationId gaTrackerData.locationType  \
# 0                 Warsaw                   3094484                       CITY
# 1                 Milano                   2802090                       CITY
# 2                Karachi                   3212296                       CITY
# 3              Bengaluru                   2940587                       CITY
# 4                    NaN                        -1                       CITY
#
#    ... map.location                      overview.industry  \
# 0  ...       Warsaw  Investment Banking & Asset Management
# 1  ...        Milan                                    NaN
# 2  ...      Karāchi                                    NaN
# 3  ...    Bengaluru                             Consulting
# 4  ...      Central                 Staffing & Outsourcing
#
#    overview.industryId          overview.revenue    overview.sector  \
# 0               200053  Unknown / Non-Applicable            Finance
# 1                    0  £25 to £50 million (GBP)                NaN
# 2                    0  Unknown / Non-Applicable                NaN
# 3               200028  Unknown / Non-Applicable  Business Services
# 4               200032  Unknown / Non-Applicable  Business Services
#
#   overview.sectorId          overview.size      overview.type  \
# 0             10010  501 to 1000 employees  Company - Private
# 1                 0   201 to 500 employees  Company - Private
# 2                 0      1 to 50 employees  Company - Private
# 3             10006   201 to 500 employees  Company - Private
# 4             10006    51 to 200 employees  Company - Private
#
#   rating.starRating salary.salaries
# 0              -0.1          2483.0
# 1               2.4          2485.0
# 2               1.5          2486.0
# 3               3.5          2487.0
# 4               3.5          2489.0
#
# [5 rows x 37 columns]

# %% [markdown]
# ## Salary Dataset Cleaning

# %%
salary = pd.read_csv("./glassdoor_data/glassdoor_salary_salaries.csv")

# %%
salary.isnull().sum().sort_values(ascending = False)
# Out:
# salary.salaries.val.salaryPercentileMap.payPercentile50    219635
# salary.salaries.val.salaryPercentileMap.payPercentile10     70406
# salary.salaries.val.salaryPercentileMap.payPercentile90     70406
# salary.salaries.val.jobTitle                                70399
# index                                                       70372
# salary.salaries.val.basePayCount                            70372
# salary.salaries.val.payPeriod                               70372
# salary.salaries.val.salaryType                              70372
# id                                                              0
# dtype: int64

# %%
salary = salary[salary['salary.salaries.val.salaryPercentileMap.payPercentile90'].notna()]
salary.head()
# Out:
#    id  index  salary.salaries.val.basePayCount salary.salaries.val.jobTitle  \
# 1   2    0.0                               9.0          Advanced Consultant
# 2   2    1.0                               7.0                   Consultant
# 3   2    2.0                               7.0            Software Engineer
# 4   2    3.0                               4.0              Project Manager
# 5   2    4.0                               3.0              Lead Consultant
#
#   salary.salaries.val.payPeriod  \
# 1                        ANNUAL
# 2                        ANNUAL
# 3                        ANNUAL
# 4                        ANNUAL
# 5                        ANNUAL
#
#    salary.salaries.val.salaryPercentileMap.payPercentile10  \
# 1                                           32257.68
# 2                                           28855.30
# 3                                           30377.86
# 4                                           38254.70
# 5                                           36724.92
#
#    salary.salaries.val.salaryPercentileMap.payPercentile90  \
# 1                                           41971.34
# 2                                           74022.00
# 3                                           38750.00
# 4                                           48675.67
# 5                                           49307.99
#
#    salary.salaries.val.salaryPercentileMap.payPercentile50  \
# 1                                           38713.25
# 2                                           38602.20
# 3                                           35032.53
# 4                                           45636.77
# 5                                           43344.02
#
#   salary.salaries.val.salaryType
# 1                       employer
# 2                       employer
# 3                       employer
# 4                       employer
# 5                       employer

# %%
salary = salary[salary['salary.salaries.val.payPeriod']=='ANNUAL']
salary = salary[salary['salary.salaries.val.jobTitle'].notna()]
salary.head()
len(salary)
# Out:
# 312699

# %%
def parse_title(title):
    title_lower = title.lower()
    
    title_list = ['data scientist', 'software engineer', 'data analyst', 'research scientist', 'business analyst',
                  'data engineer', 'statistician', 'dba', 'database engineer', 'machine learning engineer', 'applied scientist',
                 'business intelligence', 'product manager', 'sales']
    
    for val in title_list:
        if val in title_lower:
            return val.title()
   
    return title_lower.title()

salary['Cleaned Title'] = salary['salary.salaries.val.jobTitle'].apply(parse_title)
salary.head()
# Out:
#    id  index  salary.salaries.val.basePayCount salary.salaries.val.jobTitle  \
# 1   2    0.0                               9.0          Advanced Consultant
# 2   2    1.0                               7.0                   Consultant
# 3   2    2.0                               7.0            Software Engineer
# 4   2    3.0                               4.0              Project Manager
# 5   2    4.0                               3.0              Lead Consultant
#
#   salary.salaries.val.payPeriod  \
# 1                        ANNUAL
# 2                        ANNUAL
# 3                        ANNUAL
# 4                        ANNUAL
# 5                        ANNUAL
#
#    salary.salaries.val.salaryPercentileMap.payPercentile10  \
# 1                                           32257.68
# 2                                           28855.30
# 3                                           30377.86
# 4                                           38254.70
# 5                                           36724.92
#
#    salary.salaries.val.salaryPercentileMap.payPercentile90  \
# 1                                           41971.34
# 2                                           74022.00
# 3                                           38750.00
# 4                                           48675.67
# 5                                           49307.99
#
#    salary.salaries.val.salaryPercentileMap.payPercentile50  \
# 1                                           38713.25
# 2                                           38602.20
# 3                                           35032.53
# 4                                           45636.77
# 5                                           43344.02
#
#   salary.salaries.val.salaryType        Cleaned Title
# 1                       employer  Advanced Consultant
# 2                       employer           Consultant
# 3                       employer    Software Engineer
# 4                       employer      Project Manager
# 5                       employer      Lead Consultant

# %%
# get only jobs of interest

title_list = ['data scientist', 'software engineer', 'data analyst', 'research scientist', 'business analyst',
              'data engineer', 'statistician', 'dba', 'database engineer', 'machine learning engineer', 'applied scientist',
             'business intelligence', 'product manager', 'sales']

filter_list =[]

for t in title_list:
    filter_list.append(t.title())
    
salary = salary[salary['salary.salaries.val.jobTitle'].isin(filter_list)]
len(salary)
# Out:
# 23256

# %%
salary['Cleaned Title'].value_counts()
# Out:
# Software Engineer            10750
# Business Analyst              4969
# Product Manager               3496
# Sales                         2355
# Data Analyst                   863
# Research Scientist             396
# Data Scientist                 273
# Data Engineer                   82
# Business Intelligence           41
# Machine Learning Engineer       14
# Statistician                     9
# Applied Scientist                4
# Database Engineer                4
# Name: Cleaned Title, dtype: int64

# %%
# get necessary data from jobs to map countries

jobs = df_g[['map.country', 'salary.salaries']]

jobs.rename(columns={'map.country': 'Country', 'salary.salaries': 'id'}, 
                            inplace=True)

jobs = pd.merge(jobs, country_codes, left_on='Country', right_on='Name', how='left')
jobs.head()
# Out:
#     Country      id      Name Code
# 0    Poland  2483.0    Poland   PL
# 1     Italy  2485.0     Italy   IT
# 2  Pakistan  2486.0  Pakistan   PK
# 3     India  2487.0     India   IN
# 4    Israel  2489.0    Israel   IL

# %%
jobs.dropna(subset=['Code'], inplace=True)

# %%
jobs['Region'] = jobs['Code'].apply(pc.country_alpha2_to_continent_code)
jobs.drop(columns=['Name'], inplace=True)
def get_cont_name(code): 
    cont_conv_dict = {'AF': 'Africa',
                  'NA': 'North America',
                  'OC': 'Oceania',
                  'AN': 'Antarctica',
                  'AS': 'Asia',
                  'EU': 'Europe',
                  'SA': 'South America'}
    return cont_conv_dict[code] 

jobs['Region'] = jobs['Region'].apply(get_cont_name)
jobs.head()
# Out:
#     Country      id Code  Region
# 0    Poland  2483.0   PL  Europe
# 1     Italy  2485.0   IT  Europe
# 2  Pakistan  2486.0   PK    Asia
# 3     India  2487.0   IN    Asia
# 4    Israel  2489.0   IL    Asia

# %%
salary_jobs = pd.merge(salary, jobs, left_on='id', right_on='id', how='left')
salary_jobs.head()
# Out:
#    id  index  salary.salaries.val.basePayCount salary.salaries.val.jobTitle  \
# 0   2    2.0                               7.0            Software Engineer
# 1   7    3.0                               5.0             Business Analyst
# 2  12    3.0                               2.0             Business Analyst
# 3  27    3.0                               2.0              Product Manager
# 4  35    3.0                               1.0             Business Analyst
#
#   salary.salaries.val.payPeriod  \
# 0                        ANNUAL
# 1                        ANNUAL
# 2                        ANNUAL
# 3                        ANNUAL
# 4                        ANNUAL
#
#    salary.salaries.val.salaryPercentileMap.payPercentile10  \
# 0                                           30377.86
# 1                                           27177.39
# 2                                           27810.03
# 3                                           54913.08
# 4                                           29532.63
#
#    salary.salaries.val.salaryPercentileMap.payPercentile90  \
# 0                                           38750.00
# 1                                           48783.27
# 2                                           31743.78
# 3                                           80426.90
# 4                                           31909.11
#
#    salary.salaries.val.salaryPercentileMap.payPercentile50  \
# 0                                           35032.53
# 1                                           32975.96
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   salary.salaries.val.salaryType      Cleaned Title Country Code  Region
# 0                       employer  Software Engineer     NaN  NaN     NaN
# 1                       employer   Business Analyst     NaN  NaN     NaN
# 2                       employer   Business Analyst   China   CN    Asia
# 3                       employer    Product Manager  Sweden   SE  Europe
# 4                       employer   Business Analyst     NaN  NaN     NaN

# %%
salary_jobs.dropna(subset=['Country'], inplace=True)
len(salary_jobs)
# Out:
# 10606

# %%
salary_jobs.head()
# Out:
#      id  index  salary.salaries.val.basePayCount salary.salaries.val.jobTitle  \
# 2    12    3.0                               2.0             Business Analyst
# 3    27    3.0                               2.0              Product Manager
# 8    53    3.0                               1.0                        Sales
# 16  102    0.0                              22.0            Software Engineer
# 18  116    2.0                               1.0              Product Manager
#
#    salary.salaries.val.payPeriod  \
# 2                         ANNUAL
# 3                         ANNUAL
# 8                         ANNUAL
# 16                        ANNUAL
# 18                        ANNUAL
#
#     salary.salaries.val.salaryPercentileMap.payPercentile10  \
# 2                                            27810.03
# 3                                            54913.08
# 8                                            38325.99
# 16                                           26205.11
# 18                                           47995.48
#
#     salary.salaries.val.salaryPercentileMap.payPercentile90  \
# 2                                            31743.78
# 3                                            80426.90
# 8                                            41350.09
# 16                                           43448.66
# 18                                           52268.21
#
#     salary.salaries.val.salaryPercentileMap.payPercentile50  \
# 2                                                 NaN
# 3                                                 NaN
# 8                                                 NaN
# 16                                           33807.26
# 18                                                NaN
#
#    salary.salaries.val.salaryType      Cleaned Title         Country Code  \
# 2                        employer   Business Analyst           China   CN
# 3                        employer    Product Manager          Sweden   SE
# 8                        employer              Sales         Ireland   IE
# 16                       employer  Software Engineer       Singapore   SG
# 18                       employer    Product Manager  United Kingdom   GB
#
#     Region
# 2     Asia
# 3   Europe
# 8   Europe
# 16    Asia
# 18  Europe

# %%
salary_jobs = salary_jobs[['id', 'salary.salaries.val.jobTitle', 'salary.salaries.val.salaryPercentileMap.payPercentile10', 
                           'salary.salaries.val.salaryPercentileMap.payPercentile90', 'Cleaned Title', 'Country', 'Code', 'Region']]

salary_jobs.rename(columns={'salary.salaries.val.jobTitle': 'Job Title', 
                          'salary.salaries.val.salaryPercentileMap.payPercentile10': 'PayPercentile10',
                          'salary.salaries.val.salaryPercentileMap.payPercentile90': 'PayPercentile90'}, 
                            inplace=True)
salary_jobs.head()
# Out:
#      id          Job Title  PayPercentile10  PayPercentile90  \
# 2    12   Business Analyst         27810.03         31743.78
# 3    27    Product Manager         54913.08         80426.90
# 8    53              Sales         38325.99         41350.09
# 16  102  Software Engineer         26205.11         43448.66
# 18  116    Product Manager         47995.48         52268.21
#
#         Cleaned Title         Country Code  Region
# 2    Business Analyst           China   CN    Asia
# 3     Product Manager          Sweden   SE  Europe
# 8               Sales         Ireland   IE  Europe
# 16  Software Engineer       Singapore   SG    Asia
# 18    Product Manager  United Kingdom   GB  Europe

# %%
# save dataframe
salary_jobs.to_excel('./tableau_salaries.xlsx',engine='xlsxwriter', index=False)
